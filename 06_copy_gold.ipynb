# %%
from pathlib import Path
from shutil import copyfile, rmtree
import pandas as pd

# %%
DATA_DIR = Path('.') / 'data'

GOLD_LAB_DIR = DATA_DIR / 'gold_labels'
GOLD_RAW_DIR = DATA_DIR / 'gold_raw_data'

RAW_DIR = DATA_DIR / 'images'
TYPEWRITTEN_DIR = DATA_DIR / 'typewritten'

GOLD_STD = DATA_DIR / 'GoldStandard_type100.csv'

SUB_ID = 'subject_id'

# %%
rmtree(GOLD_LAB_DIR, ignore_errors=True)
rmtree(GOLD_RAW_DIR, ignore_errors=True)

GOLD_LAB_DIR.mkdir()
GOLD_RAW_DIR.mkdir()

# %%
df = pd.read_csv(GOLD_STD)
df.head()
# Out:
#    subject_id     category  class                     box  \
# 0    11782329  handwritten      1  [612, 1231, 986, 1459]
# 1    11780155  typewritten      2  [609, 1157, 966, 1460]
# 2    10667607  typewritten      2  [648, 1047, 987, 1264]
# 3    10667753  typewritten      2   [634, 965, 989, 1296]
# 4     4128205  typewritten      2    [179, 302, 292, 383]
#
#                       path                  original  predicted_class  \
# 0  data/valid/11782329.jpg  data/images/11782329.jpg                2
# 1  data/valid/11780155.jpg  data/images/11780155.jpg                2
# 2  data/valid/10667607.jpg  data/images/10667607.jpg                2
# 3  data/valid/10667753.jpg  data/images/10667753.jpg                2
# 4   data/valid/4128205.jpg   data/images/4128205.jpg                2
#
#   predicted_category                              predicted_box  \
# 0        typewritten  [ 606.3779 1229.9165  972.3797 1464.6196]
# 1        typewritten  [ 608.9484 1158.8286  962.4212 1459.6376]
# 2        typewritten  [ 641.7789 1049.3352  988.1483 1264.8937]
# 3        typewritten  [ 626.8849 1086.5962  983.1078 1289.9075]
# 4        typewritten  [179.36319 302.46603 291.9617  384.6452 ]
#
#                                       predicted_text            Date  \
# 0  Ly dvoghyWaceae\nHerbarium of Memphis State Un...   11 April 1971
# 1  University of Arkansas Herbarium (UARK)\nFlora...    30 June 2005
# 2  Herbarium of the University of North Carolina\...    3 March 1970
# 3  APPALACHIAN STATE UNIVERSITY HERBARIUM\nPLANTS...   19 April 1969
# 4  North Carolina Hi\n\n \n\nASTERACEAE\nErigecon...  30 August 2009
#
#                          Scientific_Name + Authority  \
# 0               Phacelia ranunculacea (Nutt.) Const.
# 1          Trachelospermum difforme (Walter) A. Gray
# 2                          Asplenium rhizophyllum L,
# 3                           Ophiozlossum vulgatum L,
# 4  Erigecon strigosus var, strigosus Muhlenberg e...
#
#                                  Collector Name Collector # Unnamed: 14
# 0  Elizabeth M. Browne + Edward T. Browne, Jr.     T1012 03         NaN
# 1               R. McElderry\nand J. Whisenhunt        2229
# 2                                  Dan Pittillo        3152         NaN
# 3                           I. W. Carpenter Jr.        9007         NaN
# 4                                Andrew Jenkins         387         NaN

# %%
for subject_id in df.subject_id:
    file_name = str(subject_id) + '.jpg'

    src = RAW_DIR / file_name
    dst = GOLD_RAW_DIR / file_name
    copyfile(src, dst)

    src = TYPEWRITTEN_DIR / file_name
    dst = GOLD_LAB_DIR / file_name
    copyfile(src, dst)
